# %%
import pandas as pd
import importlib
import re
import med_utils
importlib.reload(med_utils)

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
### Clinical
clinic_df = pd.read_csv("../raw_datasets/HABSHD/HD_Release_6_Clinical_FINAL.csv", low_memory=False)
clinic_df_clean = med_utils.clean_dataframe_advanced(clinic_df, missing_values=None, threshold=1, drop_rows_threshold=None, verbose=True)
# Out:
# Original shape: (5962, 1672)
# Missing values replaced: [-777777, -777777.0, -9999.0, -9999, -999, -999.0, -8888, '-9999']
# Columns dropped: 0 ([])
# Final shape: (5962, 1672)

# %%
### APOE4
apoe_df = pd.read_csv("../raw_datasets/HABSHD/HD_Release_6_Genomics_FINAL.csv", low_memory=False)
apoe_df_clean = med_utils.clean_dataframe_advanced(apoe_df, missing_values=None, threshold=1, drop_rows_threshold=None, verbose=True)
# apoe_df_clean = apoe_df_clean.drop(['APOE4_rs429358', 'APOE4_rs7412', 'APOE4_Genotype'], axis=1)
# Out:
# Original shape: (3343, 10)
# Missing values replaced: [-777777, -777777.0, -9999.0, -9999, -999, -999.0, -8888, '-9999']
# Columns dropped: 0 ([])
# Final shape: (3343, 10)

# %%
### PET-SUVR
suvr_df = pd.read_csv("../raw_datasets/HABSHD/HD_Release_6_Genomics_FINAL.csv", low_memory=False)
apoe_df_clean = med_utils.clean_dataframe_advanced(apoe_df, missing_values=None, threshold=1, drop_rows_threshold=None, verbose=True)
# apoe_df_clean = apoe_df_clean.drop(['APOE4_rs429358', 'APOE4_rs7412', 'APOE4_Genotype'], axis=1)
# Out:
# Original shape: (3343, 10)
# Missing values replaced: [-777777, -777777.0, -9999.0, -9999, -999, -999.0, -8888, '-9999']
# Columns dropped: 0 ([])
# Final shape: (3343, 10)

# %%
habs_df = med_utils.merge_dataframes(
        [clinic_df_clean, apoe_df_clean], 
        keys=['Visit_ID', 'Med_ID'],
        how='outer',
        handle_duplicates='auto',
        df_names=['clinic', 'apoe'],
        verbose=True
    )
# Out:
# Column conflicts detected:
#   'Age' appears in: ['clinic', 'apoe']
#   'Ethnicity' appears in: ['clinic', 'apoe']
#   'ID_Gender' appears in: ['clinic', 'apoe']
#   'ID_Education' appears in: ['clinic', 'apoe']
#
# Analyzing 4 column conflicts...
#   Kept 'Age' from first DataFrame (values identical)
#   Kept 'Ethnicity' from first DataFrame (values identical)
#   Kept 'ID_Gender' from first DataFrame (values identical)
#   Kept 'ID_Education' from first DataFrame (values identical)
#
# Merge completed:
# Final DataFrame shape: (5962, 1676)
# Merge key(s): ['Visit_ID', 'Med_ID']
# Merge type: outer
#
# Merge steps:
#   Step 1: Added apoe (5962 -> 5962 rows, +4 columns)

# %%
medication_columns = [col for col in habs_df.columns if re.match(r"Medication_\d+_Name", col)]
disease_map = {
    'CVD': ['CDX_Hypertension', 'IMH_HeartAttack', 'IMH_Stroke'],                            # CVD = Hypertension+ Heart attack+stroke
    'Endocrine': ['CDX_Diabetes', 'IMH_ThyroidDisease', 'IMH_HighCholesterol'],    # endocrine = Diabetes + Thyroid + high cholesterol
    'Psychiatric': ['IMH_Anxiety', 'CDX_Anxiety', 'IMH_Depression', 'CDX_Depression']       # Psychiatric = Anxiety + Depression
}
disease_columns = [col for cols in disease_map.values() for col in cols]
disease_columns_rename = list(disease_map.keys())
habs_df_selected = med_utils.rename_and_select_columns(habs_df, "../raw_datasets/naming_convension.xlsx", "HABS_HD", "New_Name", extra_cols=medication_columns+disease_columns)

# %%
habs_df_selected = med_utils.create_disease_variables(habs_df_selected, disease_map)

# %%
# 0: Male; 1: female;
print("The dimension of the selected HABS dataframe is:", habs_df_selected.shape, "with", habs_df_selected['id'].nunique(), "unique participants.")
habs_df_selected['status'] = habs_df_selected['status'].map({0: 'HC', 1: 'MCI', 2: 'AD', 9: 'Undetermine',})
habs_df_selected = habs_df_selected[habs_df_selected['status'].isin(['HC', 'MCI', 'AD'])]
print("The dimension of the selected HABS dataframe after drop unrelated with AD is:", habs_df_selected.shape, "with", habs_df_selected['id'].nunique(), "unique participants.")
habs_df_selected = med_utils.clean_status_and_demos(habs_df_selected)
habs_df_selected = habs_df_selected.dropna(subset=['status'])
habs_df_selected = habs_df_selected[~(habs_df_selected['MMSE'].isna() & habs_df_selected['CDR'].isna())]
habs_df_selected = habs_df_selected.reset_index(drop=True)
print("The dimension of the selected NACC dataframe is:", habs_df_selected.shape, "with", habs_df_selected['id'].nunique(), "unique participants.")
med_df = habs_df_selected[medication_columns]
selected_columns = habs_df_selected.columns.tolist()
# Out:
# The dimension of the selected HABS dataframe is: (5962, 48) with 3840 unique participants.
# The dimension of the selected HABS dataframe after drop unrelated with AD is: (5944, 48) with 3828 unique participants.
# Filled 0 missing status records; columns forward/back filled: ['sex', 'edu', 'APOE4']
# The dimension of the selected NACC dataframe is: (5944, 48) with 3828 unique participants.

# %% [markdown]
# ### angiotensin-converting enzyme inhibitors (ACEi)

# %%
acei_files = pd.read_excel('../raw_datasets/names.xlsx', sheet_name='ACEi')
acei_names = list(set(acei_files['Drug_name'].dropna()).union(acei_files['Brand_name'].dropna()))

# %%
acei_matched_values = med_utils.get_matched_values(med_df, acei_names)

# %%
acei_matched_values
# Out:
# ['Hydrochlorothiazide Quinapril',
#  'Ramipril',
#  'Lisinopril 20-12.5 mg HCTZ',
#  'Lisinopril-Hydrochlorothiazide 20-25mg',
#  'benazepril',
#  'Enalapril HCTZ',
#  'Fe',
#  'lisnopril',
#  'Benazapril',
#  'lisinopril-HCTZ 20-12.5mg',
#  'ENALAPRIL',
#  'Amlodipine - Benazepril',
#  'Lisinopril Hydrochlorothiazide',
#  'LISINOPRIL-HCTZ',
#  'Enalapril',
#  'Lisinopri',
#  'Benezepril',
#  'E',
#  'Lisinopril/ HCTZ 25mg',
#  'prinivil',
#  'AP',
#  'Amlodipine/Benazepril caps',
#  'Lisinopril hctz',
#  'lisinopril hctz',
#  'Lisinopril- HCTZ',
#  'Lisinporil',
#  'losinopril',
#  'Benazepril HCl',
#  'Lisinopril 10-12.5',
#  'Lisinioril',
#  'Lisinopril Hctz',
#  'lotensin',
#  'fosinopril',
#  'Prinivil',
#  'Enalapril Maleate',
#  'Lisinpril',
#  'Lizinopril',
#  'Lisinopril',
#  'Benaz',
#  'Benazepril HCTZ',
#  'lisinorpil',
#  'Benazepril',
#  'lisinopril hydrochlorothiazide',
#  'Lisinopril / Hctz',
#  'Amlodipine/Benazepril',
#  'Zestril',
#  'lisinopril-hydrochlorothiazide',
#  'LISINIPRIL',
#  'Lisionpril',
#  'Ramipril HBP',
#  'Lisinopril - HCTZ',
#  'Lisnopril',
#  'Lisinopril HCTZ 20',
#  'Fosinopril',
#  'Amlodipine Benazepril',
#  'Lisiuopril',
#  'Rampril',
#  'ala',
#  'Amlodipine/Benazepril 10-20mg',
#  'Quinapril',
#  'Zestril (lisinopril)',
#  'lisinopril/HCTZ',
#  'Captopril',
#  'D',
#  'Altace',
#  'Ca',
#  'BENAZEPRIL',
#  'lisinopril HCTZ',
#  'Lisinopril/HCTZ',
#  'lisinopril ',
#  'zestril',
#  'Lisinopril-hydrochlorothiazide',
#  'ENALAPRIL MALEATE',
#  'Linsinopril',
#  'Lisinopril 20-12.5',
#  'Lisinopril HCTZ 20-25mg',
#  'Fosinopril Sodium',
#  'Lisinopril-HCTZ',
#  'Lisinopril - BP medication',
#  'EPA',
#  'Lysinopril',
#  'ALA',
#  'Enalapril ',
#  'quinapril',
#  'lisinoprilhydrochlorothiazide',
#  'Lisinoptil',
#  'LISINOPRIL HCTZ',
#  'Lisonopril',
#  'Benazepril Hydrochloride',
#  'LISINOPRIL',
#  'Benazepril ',
#  'Enalapril maleate',
#  'Lisinopril HCTZ 2012.5mg',
#  'Benazepril/Hctz',
#  'Benazerpril',
#  'Ace',
#  'Lisinopil',
#  'Lotensin',
#  'lisinopril',
#  'C',
#  'LisinoprilhydroChlorothiazide',
#  'enalapril',
#  'Lisinopril ',
#  'Lesinopril',
#  'Benazepril HCL',
#  'Lisinopril HTCZ',
#  'lisinopril 20/12.5 mg',
#  'Lisinopril Hydrochlorothyazide',
#  'Lisinopril HCTZ']

# %%
values_to_drop_aceinames = {'Ca', 'C', 'Ace', 'E', 'ALA', 'D', 'AP', 'ala', 'EPA', 'Fe', }
acei_matched_values = [x for x in acei_matched_values if x not in values_to_drop_aceinames]

# %%
acei_all = med_utils.medication_all_timepoints(
    habs_df_selected, acei_matched_values, medication_columns, selected_columns,
    id_col="id", visit_col="visit_no"
)
# acei_all.to_csv("../preprocessed_data/HABSHD/acei_all_results_HABS_missing.csv",index=False)

# %% [markdown]
# ### angiotensin receptor blockers (ARBs)

# %%
arb_files = pd.read_excel('../raw_datasets/names.xlsx', sheet_name='ARB')
arb_names = list(set(arb_files['Drug_name'].dropna()).union(arb_files['Brand_name'].dropna()))

# %%
arb_matched_values = med_utils.get_matched_values(med_df, arb_names)

# %%
arb_matched_values
# Out:
# ['Micardis HCT',
#  'Losartan POTASSIUM',
#  'Losartan-hydrochlorothiazide',
#  'Atacand Tabs',
#  'Losartan Potassium HCTZ',
#  'LOSARTAN/HCTZ',
#  'LORSARTAN',
#  'Valsartan/HCTZ ',
#  'Telmisartan/Hydrochlorothiazide 80-25mg',
#  'Losartan Pot',
#  'Olmesartan medoxomil',
#  'Losartan HTC',
#  'Amlodipine-Olmesartan',
#  'Losartan htzt',
#  'Losartan Tab',
#  'Losartan-hctz',
#  'Losartan ',
#  'Losartan POT',
#  'ValsartanHydrochlorothiazide',
#  'Losartan/Hctz',
#  'Telmisartan ',
#  'losartan ',
#  'losartan',
#  'olmesartan medoxomil',
#  'Valsartan-HCTZ',
#  'Telmis',
#  'Losartan hctz',
#  'Losartan 100/120',
#  'Travaprost',
#  'Benicar HCT',
#  'Candesartin',
#  'LOSARTAN HCTZ',
#  'olmesartan-HCTZ',
#  'E',
#  'Travaprost Z',
#  'Edarbi',
#  'AP',
#  'losartan HCL',
#  'Losartan Potassium ',
#  'LOSARTAN',
#  'IREBESARTAN',
#  'Valsartan/HCTZ',
#  'Olmesartan (benicar)',
#  'Losartan Pottasium',
#  'Diovan',
#  'asa',
#  'Losartan (with 12 mg hydroxligen)',
#  'Losaratan',
#  'Losrtan',
#  'IRBESARTAN',
#  'Losartan Potassium and Hydrochrothiazide 100mg/25mg',
#  'Candesartan Cilexetil',
#  'Olmesartan ',
#  'Telmisartan 80 mg hydrochlorothiazide 25 mg',
#  'valsartan HCTZ',
#  'olmesartan',
#  'Telmisartan Amlodipine',
#  'Irbesartan ',
#  'VALSARTAN',
#  'Losartan HCTZ 1000',
#  'Olmesarton',
#  'Valsartan HCTZ',
#  'valsartan',
#  'Losartan HCTZ 100',
#  'Telmisartan / Hydrochlorothiazide',
#  'Valsartan',
#  'Olmesartan Medoxomil',
#  'Irbesartan (Oral Pill)',
#  'Telmisartan',
#  'TELMISARTAN',
#  'losartan HCTZ',
#  'AMLODIPINE-OLMESARTAN',
#  'losartan hydrochlorothiazide',
#  'Telmisatran',
#  'Losartan/HCTZ',
#  'Losartan Cozaar',
#  'Olmesartan Mexodomil',
#  'micardis hct',
#  'Telmisartan HCTZ (4012.5)',
#  'Valsartan and Hydrichlorothiazide 160/12.5',
#  'Olmersatan',
#  'Atacand',
#  'Irbesartan',
#  'TELMIS',
#  'Losartan Hydrochlorothiazide',
#  'amlodipine valsartan',
#  'Amlodipine/ Olmesartan',
#  'Valsartian',
#  'Telmisartan HCTZ',
#  'Olimesartan',
#  'Losartan potassium',
#  'Irbesartan HCL ',
#  'irbesartan',
#  'losartanhydrochlorothiazide ',
#  'telmisartan-hydrochlorothiazide',
#  'diovan',
#  'Losartan-HCTR',
#  'Candesartan',
#  'D',
#  'Olmesartan / Amlodipine',
#  'Diovan HCL',
#  'Telmisa',
#  'Valstartan',
#  'Olmesartan Medox/HCTZ',
#  'Benicar',
#  'Benicar ',
#  'Ca',
#  'Losartan',
#  'Losartan Potasico',
#  'Losartan  HCTZ 50',
#  'Telmasartan',
#  'losartan HCT',
#  'Olmesartan',
#  'Losartan-HCTZ',
#  'Valsartan  Hydrochlorothiazide',
#  'Micardis Telmisartan',
#  'BENICAR',
#  'Losartan HCTZ 100/12.5mg',
#  'Losartan/Hydrochlorothiazide',
#  'irbesertan',
#  'Cozaar Losartan Potassium',
#  'Tilmisartan',
#  'amlodipine/valsartan',
#  'candesartan',
#  'Azilsartan medoxomil',
#  'Losartan Potasium',
#  'Olmesartan / Hydrochlorothiazide',
#  'Losartan K',
#  'Losartan HCT',
#  'Edarbyclor (Azilsartan Medoxoml Chlorothalidone)',
#  'olmesartan medox/hctz',
#  'Losartan HCTZ (100/12.5 mg) sometimes takes 0.5 tab',
#  'Losartan Potassium & Hydrochlorothiazide',
#  'Losartan HCTZ 50mg   12.5mg',
#  'Olmesartan HCTZ',
#  'Olmesartan Medoxomil Hydrochlorothiazide',
#  'Lorsartan',
#  'Valsartan Hydrochlorothiazide',
#  'losartan potassium',
#  'Olmesartan HCTZ 40 25 mg',
#  'Losartan/HCT',
#  'Micardis',
#  'Diovan Valstartan',
#  'losartan htc',
#  'MiCardis (Telmesarten)',
#  'telmisartan',
#  'Olmesartan Hctz 20-12.5',
#  'Losartan Potassium Tablets, USP',
#  'OLMESARTAN MEDOXOMIL',
#  'ASA',
#  'C',
#  'Valsartan ',
#  'Olmesartan Medixomil',
#  'valsrtan',
#  'Losartan/ HCTZ',
#  'Azilsartan Medoxomin',
#  'Micardis Tabs',
#  'Losartan Potassium',
#  'Olmesartan HcTz 40-25 mg',
#  'Irbesartan  ',
#  'Losartan HCTZ',
#  'Losartan HCL',
#  'Olmesartan/HTC']

# %%
values_to_drop_arbnames = {'asa', 'Travaprost', 'Ca', 'C', 'E', 'Travaprost Z', 'D', 'AP', 'ASA', }
arb_matched_values = [x for x in arb_matched_values if x not in values_to_drop_arbnames]

# %%
arb_all = med_utils.medication_all_timepoints(
    habs_df_selected, arb_matched_values, medication_columns, selected_columns,
    id_col="id", visit_col="visit_no"
)
# arb_all.to_csv("../preprocessed_data/HABSHD/arb_all_results_HABS_missing.csv",index=False)

# %% [markdown]
# ### Beta Blocker

# %%
beta_blockers_files = pd.read_excel('../raw_datasets/names.xlsx', sheet_name='beta_blockers')
beta_blockers_names = list(set(beta_blockers_files['Drug_name'].dropna()).union(beta_blockers_files['Brand_name'].dropna()))

# %%
beta_blockers_matched_values = med_utils.get_matched_values(med_df, beta_blockers_names)

# %%
beta_blockers_matched_values
# Out:
# ['DORZOLAMIDE/TIMOLOL',
#  'metoprolol Succinate ER',
#  'Metoprolol Succ ER',
#  'Cardedilol',
#  'Carvedilol Coreg',
#  'Labetalol HCL',
#  'Metoprolol ER Succinate',
#  'metolprolol',
#  'Metoprolol succinate',
#  'CARVEDILOL',
#  'METROPROLOL',
#  'Metoprolol SUcc ER',
#  'Timolol Maleate (eye drops)',
#  'Timolol Hemihydrate 0.25%',
#  'metoprolol ',
#  'bisoprolol/HCT',
#  'Metoprolol BP',
#  'Metoprolol (er)',
#  'Toprol XL',
#  'CarvediloL',
#  'Dorzolamide / Timolol',
#  'Metoprolol Tartratr',
#  'timolol maleate 0.5%',
#  'propranlol',
#  'Propranolol Hcl',
#  'Caruedilol',
#  'Metoprolol Succ',
#  'LABETALOL HCL',
#  'Metoprolol tart',
#  'acebutolol',
#  'Metoprolol succER',
#  'Timolol Hemihydrate ',
#  'Metoprolol Succinate ER',
#  'Carvedilo',
#  'E',
#  'Metroprolol',
#  'Metoprolol SUCC ER',
#  'Bisoprolol fumarate',
#  'Metoprolol succ ER',
#  'Timolol Maleate',
#  'AP',
#  'Metoprolol Tartarate',
#  'Metoprolol/Tartrate',
#  'Sotalol Hcl',
#  'Atenolol',
#  'carvedilol',
#  'TOPROL XL',
#  'Bisoprolol Fumarate',
#  'timolol',
#  'Nadolol',
#  'BYSTOLIC',
#  'Carvedlol',
#  'Co Spot (dorzolamide/timolol)',
#  'Atenolol ',
#  'propranolol',
#  'coreg',
#  'labetalol',
#  'Metoprolol Succ ER ',
#  'Bisprolol',
#  'Lopressor',
#  'atenolol',
#  'Metoprolol- Tartrate',
#  'Timolol',
#  'Metoprolol Tartrate ',
#  'metropolol',
#  'Dorzolamide Hydrochloride and Timolol Maleate 0.5%',
#  'Metropolol',
#  'bisoprolol fumarate',
#  'Cavedilol',
#  'METROPOLOL',
#  'metoprolol succ ER',
#  'TIMOLOL MALEATE',
#  'Metoprolol Succinate',
#  'timolol maleate',
#  'Sotalol HCL',
#  'Bisopropol',
#  'Metopolol',
#  'Carvedilol',
#  'Propranolol ',
#  'Bisoprolo',
#  'timolol maleate 0.5% OPH SOLN',
#  'Sotalol',
#  'Corvedilol',
#  'Troprol Xl',
#  'Metoprolol & diet manager prod',
#  'propanolol',
#  'Metoprolol succinate ',
#  'Metoprolol Suc ER',
#  'ATENOLOL',
#  'Metoprolol',
#  'Bystolic ',
#  'SOTLOL',
#  'dorzolamida y timolol',
#  'METOPROLOL',
#  'Timolol GFS .5%',
#  'Metoprolol Tartrate',
#  'Propranolol',
#  'atenelol',
#  'Dorzolamide Opth Solution and Timolol (6.8mg/mL)',
#  'Labetalol ',
#  'METOPROLOL TART',
#  'Metprolol',
#  'Bisoprolol-HCTZ 5',
#  'Ziac/ Bisoprolol / HCTZ',
#  'sotalol',
#  'Metoprolol ER (Oral Pill)',
#  'Sotalol AF',
#  'metoprolol succinate',
#  'Metoprolol XL',
#  'Metolprolol',
#  'D',
#  'Timolol Maleate 0.5% Opth SOLN',
#  'Carvediol',
#  'metoprolol succinate ER',
#  'Ca',
#  'Metoprolol Succer',
#  'Metaprolol',
#  'timolol eye drops',
#  'nebivolol',
#  'Bisoprolol/HCTZ',
#  'carvediol',
#  'Timolol .5 percent',
#  'Metopropol',
#  'Propanolol',
#  'Dorzolamide Timolol',
#  'Nebivolol',
#  'Propranonol',
#  'metoprolol',
#  'Metoprotol',
#  'Propranolol ER',
#  'Dorzolamide CITimolol',
#  'Hydrochlorothiazide metoprolol tartrate',
#  'Timolol Maleate Ophthalmic Solution USP',
#  'Bisoprolol',
#  'Metoprolol  Succ ER',
#  'Carvedilol ',
#  'metoprolol tartrate',
#  'Metoprolol Tart',
#  'Sotlol',
#  'Metoprolol ER',
#  'Labetalol',
#  'Metoprolol Succinate XL',
#  'Ace',
#  'metoprolol ER',
#  'Tenormin',
#  'Lopressor (metoprolol tartrate)',
#  'Dorzolamide HCL Timolol Maleate',
#  'METOPROLOR',
#  'Metoprolol tartrate',
#  'C',
#  'Bystolic',
#  'bisoprolol',
#  'meoprolol',
#  'Metoprolol ',
#  'dorzolamide timolol',
#  'Metoprolol Succinate SR (Toprol XL)',
#  'metoprolol er',
#  'metoprolol siccinate',
#  'Metoprolol ER (succ)',
#  'Coreg',
#  'Toprol']

# %%
values_to_drop_BetaBlknames = {'Ca', 'C', 'Dorzolamide CITimolol', 'Ace', 'E', 'D', 'AP'}
beta_blockers_matched_values = [x for x in beta_blockers_matched_values if x not in values_to_drop_BetaBlknames]

# %%
beta_blockers_all = med_utils.medication_all_timepoints(
    habs_df_selected, beta_blockers_matched_values, medication_columns, selected_columns,
    id_col="id", visit_col="visit_no"
)
# beta_blockers_all.to_csv("../preprocessed_data/HABSHD/beta_blockers_all_results_HABS_missing.csv",index=False)

# %% [markdown]
# ### Calcium Channel Blockers

# %%
Ca_channel_blockers_files = pd.read_excel('../raw_datasets/names.xlsx', sheet_name='Ca_channel_blockers')
Ca_channel_blockers_names = list(set(Ca_channel_blockers_files['Drug_name'].dropna()).union(Ca_channel_blockers_files['Brand_name'].dropna()))

# %%
Ca_channel_blockers_matched_values = med_utils.get_matched_values(med_df, Ca_channel_blockers_names)

# %%
Ca_channel_blockers_matched_values
# Out:
# ['amlodipine',
#  'Amlodypine',
#  'Amlodipinebesylate',
#  'verapamil er',
#  'verapamil',
#  'Norvasc',
#  'Amlodipine-Olmesartan',
#  'Felodipine',
#  'Fe',
#  'NIFEdipine XL',
#  'Amlodipine - Benazepril',
#  'Nifedipine ER',
#  'CALCIUM',
#  'amlodpine',
#  'almodipine',
#  'Amlodipine Besytlate',
#  'Verapamil ER',
#  'Amlodipine BESYLATE',
#  'Amlodipino',
#  'Amlodipine Besylate (Oral Pill)',
#  'nifedipine',
#  'Amlodipine Tab',
#  'Amolodipine',
#  'E',
#  'AP',
#  'Amlodipine/Benazepril caps',
#  'Amlodipine-besylate',
#  'NAC',
#  'Amlodipine Besylate',
#  'amlodipine besylate',
#  'Amlodipine besylarte',
#  'Amlodipene',
#  'Nifedipine',
#  'nifedipine ER',
#  'AMLODIPINE BESYLATE',
#  'calcium',
#  'Amlodipine Bestlate',
#  'Nifedipine XL',
#  'AMLOD',
#  'Nifedipine (Extended Release)',
#  'Telmisartan Amlodipine',
#  'Cardizem Caps',
#  'amlodepine',
#  'Cardizem',
#  'Amlodopine',
#  'AmLodipine',
#  'felodipine ER',
#  'Amlodipine besylate tablets',
#  'NIFEdipine',
#  'Verapamil SR',
#  'Amlod',
#  'Calcium +',
#  'Amlodipine tab',
#  'AMLODIPINE-OLMESARTAN',
#  'Amlodipine  Besylate',
#  'Amlodipine besylate',
#  'diltiazem',
#  'amLODIPIne',
#  'Amlodipine/Benazepril',
#  'AMLODIPINE-BESYLATE',
#  'amLodipine',
#  'amlodipine valsartan',
#  'Amlodipine/ Olmesartan',
#  'DILTIAZEM',
#  'amlodipine Besylate',
#  'Amlodipine (Norvasc)',
#  'Amlodipine',
#  'Amlodipine Besylate Zydus',
#  'amlodipjne',
#  'Amlodipine Benazepril',
#  'amalodipine',
#  'ala',
#  'Norvac',
#  'Amlodipine/Benazepril 10-20mg',
#  'Verapamil 24 HR ER',
#  'Verapamil HCL',
#  'Amlodipine Bensylate',
#  'D',
#  'Amlodipine Benaz',
#  'Olmesartan / Amlodipine',
#  'Amlodipine Besylate ',
#  'amlodipine 5mg',
#  'Ca',
#  'amLodipine Besylate',
#  'norvasc',
#  'AMLODIPINE',
#  'Diltiazem',
#  'Tiazac ER',
#  'Felodipine ER',
#  'Amlodipin',
#  'amlodipine/valsartan',
#  'procardia xl',
#  'ditiazem',
#  'Amlodapine',
#  'ALA',
#  'NORVASC',
#  'Nifedipine ',
#  'Nifedapine',
#  'dilTIAZem',
#  'Norvasc generic',
#  'Calcium',
#  'verapamil ER',
#  'Amilodipine',
#  'amLODIPine (NORVASC)',
#  'NIFEdipine CC',
#  'Verapamil',
#  'Nisoldipine ER',
#  'Amdlodipine',
#  'C',
#  'Amlodepine',
#  'Nifedipine Er',
#  'Amlodipine/Besylate',
#  'Norvas',
#  'Calcium ',
#  'Amlodipine besylate  ',
#  'Amlodipine ']

# %%
values_to_drop_CCBnames = {'CALCIUM', 'Ca', 'C', 'Calcium', 'Calcium ', 'E', 'ALA', 'D', 'AP', 'calcium', 'ala', 'NAC',
                           'Fe', 'Calcium +'}
Ca_channel_blockers_matched_values = [x for x in Ca_channel_blockers_matched_values if x not in values_to_drop_CCBnames]

# %%
Ca_channel_blockers_all = med_utils.medication_all_timepoints(
    habs_df_selected, Ca_channel_blockers_matched_values, medication_columns, selected_columns,
    id_col="id", visit_col="visit_no"
)
# Ca_channel_blockers_all.to_csv("../preprocessed_data/HABSHD/Ca_channel_blockers_all_results_HABS_missing.csv",index=False)

# %% [markdown]
# ### Diuretics

# %%
diuretics_files = pd.read_excel('../raw_datasets/names.xlsx', sheet_name='diuretics')
diuretics_names = list(set(diuretics_files['Drug_name'].dropna()).union(diuretics_files['Brand_name'].dropna()))

# %%
diuretics_matched_values = med_utils.get_matched_values(med_df, diuretics_names)

# %%
diuretics_matched_values
# Out:
# ['Losartan-hydrochlorothiazide',
#  'Spironolactone ',
#  'Hydrochlorothiazide Quinapril',
#  'SPironolactone',
#  'Telmisartan/Hydrochlorothiazide 80-25mg',
#  'Spinolactone',
#  'Spironolactone HCTZ',
#  'Iron ',
#  'Hydrochlorothiazidy',
#  'spironolactone',
#  'Hydrochlorothiazide DE',
#  'lasix',
#  'Hydrochlorothyazide',
#  'Furosemide (Lasix)',
#  'Lisinopril-Hydrochlorothiazide 20-25mg',
#  'Iron',
#  'iron',
#  'Termisartan/Hydrochlorothiazide (MICARDES HCL) 80/20',
#  'ValsartanHydrochlorothiazide',
#  'HYDROCHLOROTHIAZIDE',
#  'indapamide',
#  'furosemine',
#  'triamterene HCTZ',
#  'Spironoloctone',
#  'hydrochlorot',
#  'Triamterene (Diazide)',
#  'Lisinopril Hydrochlorothiazide',
#  'Amox',
#  'E',
#  'Triamt',
#  'Spironalactone',
#  'AP',
#  'Hydrochlorothiaz',
#  'triamterene',
#  'Triampterene',
#  'Hydrochlrothiazide',
#  'Triamterene HCTZ ',
#  'Hydroclorothiazide',
#  'Triamterene/HCTZ',
#  'hydroCHLorothiaz',
#  'Acetazolamide',
#  'Nadolol',
#  'HYDROCLOROTHIAZIDE',
#  'Furosimide',
#  'Hydrochlorothiazide ',
#  'FUROSEMIDE',
#  'Hydrochorthiazide',
#  'Furosemide ',
#  'Telmisartan 80 mg hydrochlorothiazide 25 mg',
#  'Atenolol and Chlorthalidone',
#  'Hydrochlorothiazide',
#  'EPLERENONE',
#  'Spirolactone',
#  'triamterene hctz',
#  'Clorothalidone',
#  'torsemide',
#  'Sprionolactone',
#  'potassium',
#  'Chlortalidone',
#  'Hydrochlorothiazied',
#  'IRON',
#  'Hyadrochlorothiazide',
#  'eplerenone',
#  'Telmisartan / Hydrochlorothiazide',
#  'hydrochlorothiazide',
#  'Amilorid',
#  'Lasix (Furosemide)',
#  'Spirinolactone',
#  'Potassium',
#  'Indapamide',
#  'losartan hydrochlorothiazide',
#  'Spironolacton',
#  'hydroCHLOROthiazide',
#  'potassium ',
#  'Valsartan and Hydrichlorothiazide 160/12.5',
#  'lisinopril hydrochlorothiazide',
#  'Lasix ',
#  'Eplerenone',
#  'Triamterene',
#  'Triametrene',
#  'Bumetanide',
#  'lisinopril-hydrochlorothiazide',
#  'Losartan Hydrochlorothiazide',
#  'Hidroclorotiazida (Hydrochlorothiazide)',
#  'Chlorthlidone',
#  'Spironolactone',
#  'Furosemide',
#  'Triamterene / Hydrochlorothiazide',
#  'Spitonolactone',
#  'Fursosemide',
#  'losartanhydrochlorothiazide ',
#  'POTASSIUM',
#  'telmisartan-hydrochlorothiazide',
#  'Potassium ',
#  'Dyazide triamterene hydrochlorothiazide\t',
#  'Furisemide',
#  'hydrochlorithiazide',
#  'D',
#  'Triamterene HCTZ (37.5 to 25 mg)',
#  'Triam',
#  'Ca',
#  'Torsemide',
#  'furosemide',
#  'Espironolactona',
#  'HydroCHLOROthiaz',
#  'Lisinopril-hydrochlorothiazide',
#  'Valsartan  Hydrochlorothiazide',
#  'Losartan/Hydrochlorothiazide',
#  'Chlorthalidone ',
#  'Chlorthalidone',
#  'Hydrochlorot',
#  'SPIRONOLACTONE',
#  'Hydrochlorothiazide HCTZ',
#  'Hydrochorothiazide',
#  'Olmesartan / Hydrochlorothiazide',
#  'Flurosemide',
#  'Hydrochlorothiazide metoprolol tartrate',
#  'Hydrochlorothizide',
#  'Triamterene-HCTZ',
#  'lisinoprilhydrochlorothiazide',
#  'Hydochlorothiazide',
#  'Losartan Potassium & Hydrochlorothiazide',
#  'Hydrochlothiazide',
#  'Triamterene ',
#  'Metolazone',
#  'Spironolcatone',
#  'Olmesartan Medoxomil Hydrochlorothiazide',
#  'Valsartan Hydrochlorothiazide',
#  'hydrochlorothiaziade',
#  'Furosemine',
#  'Ace',
#  'Lasix',
#  'bumetanide',
#  'furoemide',
#  'spironolact/aldactone',
#  'C',
#  'Spironolacto',
#  'LisinoprilhydroChlorothiazide',
#  'chlorthalidone',
#  'Furosemide Lasix',
#  'hydrochlorothiaz',
#  'Hyrdrochlorothiazide',
#  'Triamterene HCTZ',
#  'Hydrochlorothialide',
#  'ACET',
#  'Hydrocholorothizide',
#  'Hydrocholorothiazide']

# %%
values_to_drop_diureticsnames = {'Ca', 'C', 'IRON', 'Ace', 'E', 'POTASSIUM', 'potassium', 'D', 'AP', 'Potassium',
                                 'Potassium ', 'ACET', 'Iron', 'Iron ', 'potassium ', 'Amox', 'iron'}
diuretics_matched_values = [x for x in diuretics_matched_values if x not in values_to_drop_diureticsnames]

# %%
diuretics_all = med_utils.medication_all_timepoints(
    habs_df_selected, diuretics_matched_values, medication_columns, selected_columns,
    id_col="id", visit_col="visit_no"
)
# diuretics_all.to_csv("../preprocessed_data/HABSHD/diuretics_all_results_HABS_missing.csv",index=False)

# %% [markdown]
# ### statins

# %%
statin_files = pd.read_excel('../raw_datasets/names.xlsx', sheet_name='statin')
statin_names = list(set(statin_files['Drug_name'].dropna()).union(statin_files['Brand_name'].dropna()))

# %%
statin_matched_values = med_utils.get_matched_values(med_df, statin_names)

# %%
statin_matched_values
# Out:
# ['Simuastatin',
#  'pravastatin SOD',
#  'rosuvastatin calcium',
#  'atorvastafin',
#  'Crestor (Generic Drug: Rosuvastatin)',
#  'Atorvastatin Calcium/Lipitor',
#  'Atorvastatin calcium ',
#  'SIMVASTATIN',
#  'Rosuvastatin Ca',
#  'Atorvistatin',
#  'EzetimibeSimvastatin',
#  'Atorvastatin Ca',
#  'Crestor/Rosuvastatin calcium)',
#  'Atorvastain ',
#  'Crestor Rosuvastatin',
#  'Livalo ',
#  'Lipitor (Atorvastatin)',
#  'simvastatin',
#  'Rosuvastatin calcium',
#  'RUVASTATIN',
#  'CRESTOR',
#  'ROSUVASTATIN CA',
#  'Simvistatin',
#  'Rosubastatin',
#  'Pravastatine',
#  'LOVASTATIN',
#  'PRAVASTATIN',
#  'Atrorvastatin',
#  'Pravstatin',
#  'atorvasatatin',
#  'ATORVASTATIN',
#  'ATORVASTATIN CALCIUM',
#  'AFORVASTATIN',
#  'Lipitor',
#  'Pravastatin ',
#  'Sivastatin',
#  'rosuvastatin CA',
#  'E',
#  'Rosuvastatin',
#  'Atorvastatin Lipitor',
#  'Pravastatin',
#  'Atorvastatin Calcium Tablets, USP',
#  'Rosuvostatin ',
#  'Proavastatine',
#  'Rosuvastain',
#  'Atorvastatin Clacium',
#  'Crestor Rosuvastatin Calcium',
#  'atorvastatin (LIPITOR)',
#  'Atorovastatin',
#  'Rosuvatatin',
#  'Pitavastatin',
#  'Atorvastatin Tab',
#  'Livalo',
#  'SIMVASTATIN 10',
#  'pravastatin',
#  'statin',
#  'prevastatin',
#  'Pravastatin SOD Tab',
#  'Rosuvastatin tabs',
#  'ATROVASTATIN',
#  'rosuvastatin',
#  'Simvastatin ABS',
#  'Pitavastatin Calcium',
#  'Simvastin',
#  'Atorvastatin (has stopped taking it for over a year)',
#  'Atorbastatin',
#  'Study med (atorvastatin or placebo)',
#  'Pravastatin Na',
#  'PRABASTATIN',
#  'Atotvastatin',
#  'Pravastatin Sodium',
#  'Atorvasatin',
#  'zocor',
#  'lipitor ',
#  'Atorvastatina',
#  'Atorvastatin',
#  'pravastatin sodium',
#  'ROSUVASTATIN CAL',
#  'Atoruastatin',
#  'ATORVAStatin',
#  'Atorvastatin Calcium ',
#  'lipitor tabs',
#  'Simvastating',
#  'Pravastatin Sodium ',
#  'Rosuvastatin ',
#  'simvostatin',
#  'Atorvastatina (Atorvastatin)',
#  'ROSUVASTATIN',
#  'Atrovastatin',
#  'Astorvatatin',
#  'atrovastatin',
#  'atoruastatin',
#  'Rosuvastatin Calcium',
#  'Atorvastatiin',
#  'Rosuvastatin Tab',
#  'atorvastatin',
#  'Prevastatin',
#  ' Atorvastatin ',
#  'crestor',
#  'atorvastatin ',
#  'pravastin',
#  'amLopidipine atorvastatin ',
#  'Rouvastatin',
#  'Simvastasin',
#  'Rosuvastatin Calcium ',
#  'Crestor rosuvastatin',
#  'Pravachol',
#  'Rovastatin',
#  'Rosuvastatin Ca + (Crestor)',
#  'Symvastatin',
#  'Atortvastatin ',
#  'Atorvastatin ',
#  'Simvastain',
#  'Statin',
#  'Sinvastatin',
#  'ATOVASTATIN',
#  'Atorvastatin calcium',
#  'Atoravastatin',
#  'Astorvastattin',
#  'atorvastatin lipitor',
#  'Crestor Oral',
#  'ROSUVATASTIN',
#  'Rosuvastatin Tabs',
#  'Rusuvastatin',
#  'Atorvarstatin',
#  'Pravastatin SOD',
#  'atorvastatin (Lipitor)',
#  'ROSUVASTATIN CALCIUM',
#  'Liptor',
#  'Fluvastatin ER',
#  'atorvastatin calcium',
#  'generic crestor',
#  'Rosuvastatin CA',
#  'Simvastatin',
#  'Crestor (Oral Pill)',
#  'Rosavastatin',
#  'Simvastatin ',
#  'Crestor rosuvastatin calcium',
#  'Ezetimbe/simvastatin',
#  'ezetimibe simvastatin',
#  'Pravastatin sodium',
#  'livalo',
#  'Provastatin',
#  'ROSVASTATIN',
#  'Artovastatin',
#  'Atorvastain',
#  'Atorvastin',
#  'Lovastatin ',
#  'Pervastatin',
#  'Lovastatin',
#  'Pravastatin Sodium  Tablet',
#  'PROVASTATIN',
#  'pravatatin',
#  'Crestor ',
#  'Atorvastatin (Lipitor)',
#  'C',
#  'lipitor',
#  'Atorvastatin  Calcium',
#  'LIPITOR',
#  'Pravastatin Sodium  ',
#  'Rosuvastatine Calcium',
#  'Atorvastatin Advanced D',
#  'Crestor',
#  'Pravastatin Sod',
#  'lovastatin',
#  'Atorvastatin Calcium',
#  'Pravastatin Calcium',
#  'Rosuvastin',
#  'Atorvatatin',
#  'Liitor',
#  'Zocor']

# %%
values_to_drop_statinnames = {'C', 'E'}
statin_matched_values = [x for x in statin_matched_values if x not in values_to_drop_statinnames]

# %%
statin_all = med_utils.medication_all_timepoints(
    habs_df_selected, statin_matched_values, medication_columns, selected_columns,
    id_col="id", visit_col="visit_no"
)
# statin_all.to_csv("../preprocessed_data/HABSHD/statin_all_results_HABS_missing.csv",index=False)

# %% [markdown]
# ### metformin

# %%
metformin_files = pd.read_excel('../raw_datasets/names.xlsx', sheet_name='metformin')
metformin_names = list(set(metformin_files['Drug_name'].dropna()).union(metformin_files['Brand_name'].dropna()))

# %%
metformin_matched_values = med_utils.get_matched_values(med_df, metformin_names)

# %%
metformin_matched_values
# Out:
# ['metoformin',
#  'Metformin HCL ',
#  'Metformin/ hydrochloride',
#  'Metformin HCL ER',
#  'Glucophage Metformin',
#  'Metformin HCI',
#  'metformin hydrochloride',
#  'Glipizide-Metformin',
#  'metFORMIN Hcl',
#  'glucophage',
#  'Metformin er',
#  'Metformin hcl',
#  'Metoformin',
#  'metformin HCL ER',
#  'glipizide-metformin',
#  'metFORMIN XR',
#  'Metformin ',
#  'Metformin HCl',
#  'Metformin',
#  'Metformin Hydrochloride',
#  'metFormin',
#  'Metaformin',
#  'METFORMIN',
#  'Metformin HCL',
#  'Metformin ER',
#  'Metformin HCL XR',
#  'metformin',
#  'Metformin Extended',
#  'metformin XL',
#  'Metformin Extended Release',
#  'Metformin XL',
#  'Metformin HcI',
#  'Metformin XR',
#  'MetFormin HCL',
#  'C',
#  'metformin (Glucophage XR)',
#  'Metformina',
#  'D',
#  'Pioglitazone-Metformin',
#  'Metformin Hcl',
#  'metformin time release',
#  'Glipizide Metformin',
#  'metformin HCL',
#  'Glucophage XR',
#  'metformin ER',
#  'Kombiglyze XR',
#  'Glyburide-Metformin',
#  'METFORMIN HCL XR',
#  'metformin ',
#  'METFORMIN HCL',
#  'Metformin HCL er',
#  'Sitagliptin and Metformin HCl',
#  'Meformin',
#  'Janumet XR (sitagliptin & metformin HCL)',
#  'METAFORMIN',
#  'Metformin HCl ER',
#  'metformin hcl',
#  'E',
#  'Pioglitazone Metformin',
#  'Metformin HCL 1,000 Mg']

# %%
values_to_drop_metforminnames = {'E', 'C', 'D'}
metformin_matched_values = [x for x in metformin_matched_values if x not in values_to_drop_metforminnames]

# %%
metformin_all = med_utils.medication_all_timepoints(
    habs_df_selected, metformin_matched_values, medication_columns, selected_columns,
    id_col="id", visit_col="visit_no"
)
# metformin_all.to_csv("../preprocessed_data/HABSHD/metformin_all_results_HABS_missing.csv",index=False)

# %% [markdown]
# ### control group
# never have any of the 5 type of medications

# %%
drug_lists = [
    acei_matched_values,
    arb_matched_values,
    beta_blockers_matched_values,
    Ca_channel_blockers_matched_values,
    diuretics_matched_values,
    statin_matched_values,
    metformin_matched_values
]

all_target_drugs = set().union(*drug_lists)

# %%
row_has_target_drug = (
    habs_df_selected[medication_columns]
      # .applymap(lambda x: med_utils.contains_any_medication_type(x, all_target_drugs))
      .apply(lambda col: col.map(lambda x: med_utils.contains_any_medication_type(x, all_target_drugs)))
      .any(axis=1)
)
ids_with_any_target_drug = habs_df_selected.loc[row_has_target_drug, 'id'].unique()
controls_df = habs_df_selected[~habs_df_selected['id'].isin(ids_with_any_target_drug)].copy()

# %%
controls_df["Has_Medication_This_Visit"] = False
controls_df = controls_df.drop(columns=[c for c in medication_columns if c in controls_df.columns])
# controls_df.to_csv("../preprocessed_data/HABSHD/controls_df_HABS_missing.csv",index=False)

# %% [markdown]
# ### Adjust for the later modelling in R

# %%
datasets = {
    "ACEi": acei_all,
    "ARB": arb_all,
    "BetaBlk": beta_blockers_all,
    "CCB": Ca_channel_blockers_all,
    "Diuretic": diuretics_all,
    "Statin": statin_all,
    "Metformin": metformin_all,
    "Control": controls_df  
}

# %%
merged_df = med_utils.merge_medication_longitudinal(datasets, control_key="Control", extra_cols=["visit_no", "MMSE", "CDR"]+disease_columns_rename)

# %%
med_cols = ['ACEi', 'ARB', 'BetaBlk', 'CCB', 'Diuretic', 'Statin', 'Metformin']
disease_cols = ['CVD', 'Endocrine', 'Psychiatric']

# participant never took ANY medication across ALL visits
med_control = (
    ~merged_df.groupby('id')[med_cols]
    .transform('any')
    .any(axis=1)
)

# participant never had ANY disease across ALL visits
disease_control = (
    ~merged_df.groupby('id')[disease_cols]
    .transform('any')
    .any(axis=1)
)

merged_df['Med_Control'] = med_control
merged_df['Disease_Control'] = disease_control
merged_df['Total_Disease'] = merged_df[disease_cols].sum(axis=1)

# %%
print(f"Initial rows: {len(merged_df)}")
merged_clean = merged_df.dropna(subset=['status'])
# merged_clean = merged_clean[~(merged_clean['MMSE'].isna() & merged_clean['CDR'].isna())]
merged_clean = merged_clean[~(merged_clean['CDR'].isna())]
print(f"After dropping missings: {len(merged_clean)}")
merged_clean = merged_clean[merged_clean.groupby('id')['visit_no'].transform('nunique') > 1]
print(f"After removing number of records: {len(merged_clean)}")
# Out:
# Initial rows: 5931
# After dropping missings: 5930
# After removing number of records: 3537

# %%
merged_clean['visit_date'].isna().sum()
# Out:
# np.int64(0)

# %%
merged_clean['visit_date'] = pd.to_datetime(merged_clean['visit_date'])
merged_clean['months_since_baseline'] = (
    merged_clean.groupby('id')['visit_date']
      .transform(lambda x: (x - x.min()) / pd.Timedelta(days=30.4375))
      .round()
    .astype(int)
)
merged_clean['year_since_baseline'] = (merged_clean['months_since_baseline']/ 12).round(2)

# %%
merged_clean = med_utils.clean_and_filter_participants(
    merged_clean,
    id_col='id',
    class_col ='status',
    time_col = 'visit_no',
    medication_ever_col=None,
    min_visits=2,
    if_print=True
)
# Out:
# Remaining participants: 1,425
# Dropped participants:   0

# %%
merged_clean[merged_clean.duplicated(subset=['id', 'visit_no'], keep=False)].sort_values(['id','visit_no'])
# Out:
# Empty DataFrame
# Columns: [id, visit_date, status, age, sex, edu, APOE4, ACEi, ARB, BetaBlk, CCB, Diuretic, Statin, Metformin, Total_Meds, visit_no, MMSE, CDR, CVD, Endocrine, Psychiatric, Med_Control, Disease_Control, Total_Disease, months_since_baseline, year_since_baseline]
# Index: []
#
# [0 rows x 26 columns]

# %%
merged_clean = med_utils.clean_longitudinal(merged_clean)

# %%
merged_clean.to_csv("../preprocessed_data/HABSHD/HABSHD_merge_full_missing.csv",index=False)

# %%
(merged_clean.isna().mean()*100).sort_values(ascending=False).round(2)
# Out:
# APOE4                    2.23
# MMSE                     1.22
# id                       0.00
# Total_Meds               0.00
# months_since_baseline    0.00
# Total_Disease            0.00
# Disease_Control          0.00
# Med_Control              0.00
# Psychiatric              0.00
# Endocrine                0.00
# CVD                      0.00
# CDR                      0.00
# visit_no                 0.00
# Metformin                0.00
# visit_date               0.00
# Statin                   0.00
# Diuretic                 0.00
# CCB                      0.00
# BetaBlk                  0.00
# ARB                      0.00
# ACEi                     0.00
# edu                      0.00
# sex                      0.00
# age                      0.00
# status                   0.00
# year_since_baseline      0.00
# dtype: float64

# %%
med_result = merged_clean.groupby('id')[med_cols].nunique().eq(1)
med_summary = med_result.mean()
med_always_true = (merged_clean.groupby('id')[med_cols].sum() == merged_clean.groupby('id')[med_cols].count())
med_summary
# Out:
# ACEi         0.863158
# ARB          0.867368
# BetaBlk      0.880000
# CCB          0.881404
# Diuretic     0.878596
# Statin       0.758596
# Metformin    0.889825
# dtype: float64

# %%
dis_result = merged_clean.groupby('id')[disease_cols].nunique().eq(1)
dis_summary = dis_result.mean()
dis_always_one = merged_clean.groupby('id')[disease_cols].min().eq(1)
dis_summary
# Out:
# CVD            0.835789
# Endocrine      0.856140
# Psychiatric    0.851930
# dtype: float64

# %%
max_tab = merged_clean.groupby('id')['Total_Meds'].max().value_counts()
print("\nDistribution of max Total_Meds per participant:\n", max_tab)
# Out:
# Distribution of max Total_Meds per participant:
#  Total_Meds
# 0    368
# 1    336
# 2    295
# 3    260
# 4    125
# 5     36
# 6      5
# Name: count, dtype: int64

# %%
max_tab2 = merged_clean.groupby('id')['Total_Disease'].max().value_counts()
print("\nDistribution of max Total_Disease per participant:\n", max_tab2)
# Out:
# Distribution of max Total_Disease per participant:
#  Total_Disease
# 2    619
# 3    390
# 1    323
# 0     93
# Name: count, dtype: Int64

# %%
# // PLEASE IGNORE BELOW. THIS IS JUST TO LOAD THE FINAL CLEANED DATASET FOR ANALYSIS, NOT THE PREPROCESSING STEPS.
# THE ONLY IMPUTED VARIABLE IS APOE4 WITH ONLY 2.2% MISSINGNESS, AND WE IMPUTED IT WITH NISSRANGER IN R.
# have the same function and result in Tables.Rmd
merged_clean = pd.read_csv('../preprocessed_data/HABSHD/HABSHD_cdr_imputed.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[127], line 4
#       1 # // PLEASE IGNORE BELOW. THIS IS JUST TO LOAD THE FINAL CLEANED DATASET FOR ANALYSIS, NOT THE PREPROCESSING STEPS.
#       2 # THE ONLY IMPUTED VARIABLE IS APOE4 WITH ONLY 2.2% MISSINGNESS, AND WE IMPUTED IT WITH NISSRANGER IN R.
#       3 # have the same function and result in Tables.Rmd
# ----> 4 merged_clean = pd.read_csv('../preprocessed_data/HABSHD/HABSHD_cdr_imputed.csv')
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/site-packages/pandas/io/common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../preprocessed_data/HABSHD/HABSHD_cdr_imputed.csv'

# %%
groups, labelled_df = med_utils.split_by_progression(merged_clean)

# %%
summary_df = med_utils.baseline_summary(labelled_df)
summary_df

# %%
med_cols_names = ["ACEi", "ARB", "BetaBlk", "CCB", "Diuretic", "Statin", "Metformin"]
med_utils.baseline_age_by_med(merged_clean, med_cols_names)
